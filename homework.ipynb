# %%
# selenium 起手式
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager

# 建立 Service 物件，指定 chromedriver.exe 的路徑
service = Service()

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://24h.pchome.com.tw/")

import time

# %%
driver.find_element(By.CSS_SELECTOR, ".c-search__input").send_keys("潛水蛙鞋")
driver.find_element(By.CSS_SELECTOR, ".c-search__btn.c-search__btn--search").click()

# %%
try:
        next_btn = driver.find_element(By.CSS_SELECTOR, ".c-pagination__button.is-next > button") 
        next_btn.click()
        time.sleep(2)
    except:
        None_next_btn = driver.find_element(By.CSS_SELECTOR, ".c-pagination__button.is-next span.is-disabled")
        print("沒有下一頁，爬取完成。")
        break

# %%
#計算整個頁面的數量 
item_list = driver.find_elements(By.CSS_SELECTOR, ".c-listInfoGrid__item")
print(item_list)
print(len(item_list))

# %%
#單頁

# selenium 起手式
import json
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.common.exceptions import NoSuchElementException
# from webdriver_manager.chrome import ChromeDriverManager

# 建立 Service 物件，指定 chromedriver.exe 的路徑
service = Service()

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)

import time
driver.get("https://24h.pchome.com.tw/")
driver.find_element(By.CSS_SELECTOR, ".c-popUp__endBtn > button").click()
time.sleep(2)
driver.find_element(By.CSS_SELECTOR, ".c-search__input").send_keys("潛水蛙鞋")
driver.find_element(By.CSS_SELECTOR, ".c-search__btn.c-search__btn--search").click()

#抓到第一筆的詳細資料
All_items   = []
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(3)
item_list = driver.find_elements(By.CSS_SELECTOR, ".c-listInfoGrid__item")
for item in item_list:
    Product_name = item.find_element(By.CSS_SELECTOR, ".c-prodInfoV2__title").text
    Product_price = item.find_element(By.CSS_SELECTOR, ".c-prodInfoV2__price").text
    Product_img = item.find_element(By.CSS_SELECTOR, ".c-prodInfoV2__img > img").get_attribute("src")
    Product_href = item.find_element(By.CSS_SELECTOR, "a").get_attribute("href")

    All_items.append({
        "name" : Product_name ,  
        "price" : Product_price ,
        "img" : Product_img ,  
        "href" : Product_href
        })
        
print(json.dumps(All_items, ensure_ascii=False, indent=2))

print("總筆數：", len(All_items))

# %%
#多頁

# selenium 起手式
import json
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.common.exceptions import NoSuchElementException
# from webdriver_manager.chrome import ChromeDriverManager

# 建立 Service 物件，指定 chromedriver.exe 的路徑
service = Service()

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)

import time
driver.get("https://24h.pchome.com.tw/")
driver.find_element(By.CSS_SELECTOR, ".c-popUp__endBtn > button").click()
time.sleep(2)
driver.find_element(By.CSS_SELECTOR, ".c-search__input").send_keys("XBOX控制器")
driver.find_element(By.CSS_SELECTOR, ".c-search__btn.c-search__btn--search").click()

#抓到第一筆的詳細資料
All_items   = []
page_count = 1
while True:
    print(f"\n--- 正在爬取第 {page_count} 頁 ---")
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)
    item_list = driver.find_elements(By.CSS_SELECTOR, ".c-listInfoGrid__item")
    for item in item_list:
        Product_name = item.find_element(By.CSS_SELECTOR, ".c-prodInfoV2__title").text
        Product_price = item.find_element(By.CSS_SELECTOR, ".c-prodInfoV2__price").text
        Product_img = item.find_element(By.CSS_SELECTOR, ".c-prodInfoV2__img > img").get_attribute("src")
        Product_href = item.find_element(By.CSS_SELECTOR, "a").get_attribute("href")

        All_items.append({
            "name" : Product_name ,  
            "price" : Product_price ,
            "img" : Product_img ,  
            "href" : Product_href
            })
        
    
    try:
        #找到案紐且沒有disabled屬性 
        next_page_button = driver.find_element(By.CSS_SELECTOR, "div.c-pagination__button.is-next > button:not([disabled])")
        # 如果找到下一頁按鈕，就點擊並繼續迴圈
        next_page_button.click()
        page_count += 1
        time.sleep(3) # 點擊後等待新頁面載入
        
    except NoSuchElementException:
        # 如果找不到符合 "沒有 [disabled] 屬性" 的按鈕，代表已到達最後一頁
        print("已到達最後一頁，停止爬取。")
        break # 跳出 while 迴圈      
        

print("\n======================================")
print(" 爬取完成！")
print(json.dumps(All_items, ensure_ascii=False, indent=2))
print("總筆數：", len(All_items))
# Out:
# --- 正在爬取第 1 頁 ---
#
# --- 正在爬取第 2 頁 ---
#
# --- 正在爬取第 3 頁 ---
#
# --- 正在爬取第 4 頁 ---
# 已到達最後一頁，停止爬取。
#
# ======================================
#  爬取完成！
# [
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把 磨砂黑 台灣公司貨",
#     "price": "$1,590",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900HTBDQ/000001_1726631072.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900HTBDQ"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把 冰雪白 台灣公司貨",
#     "price": "$1,590",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900J87CE/000001_1757559159.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900J87CE"
#   },
#   {
#     "name": "ASUS ROG 華碩 ASUS ROG 雷切 Raikiri Pro PC 無線電競控制器 手把 台灣公司貨 可用於XBOX/PC",
#     "price": "$3,990",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900HHOUS/000001_1745810188.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900HHOUS"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把《叢林風暴》特別版 台灣公司貨",
#     "price": "$1,690",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900HZZY2/000001_1729569683.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900HZZY2"
#   },
#   {
#     "name": "Microsoft 微軟 XBOX 手把 無線控制器+手把接收器(裸裝)組合-磨砂黑",
#     "price": "$2,350",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900JD9GU/000001_1761104853.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900JD9GU"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把 衝擊藍 台灣公司貨",
#     "price": "$1,690",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900HTBCP/000001_1726630965.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900HTBCP"
#   },
#   {
#     "name": "Xbox 微軟 無線控制器 手把",
#     "price": "$1,690",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAH1900J4FQ9/000001_1755050712.png?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-1900J4FQ9"
#   },
#   {
#     "name": "Microsoft 微軟 XBOX 手把 無線控制器+手把接收器(裸裝)組合-冰雪白",
#     "price": "$2,350",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900JD9GT/000001_1761104844.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900JD9GT"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把《毀滅戰士：黑暗時代》特仕版 台灣公司貨",
#     "price": "$2,290",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900IUCUD/000001_1747806242.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900IUCUD"
#   },
#   {
#     "name": "RAZER 雷蛇 Wolverine V3 Pro 金鋼狼 無線電競控制器For PC Xbox RZ06-05200100-R3M1",
#     "price": "$6,243",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJOYA900HUTQJ/000001_1727080047.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJOY-A900HUTQJ"
#   },
#   {
#     "name": "Microsoft 微軟 XBOX ONE Elite Series 2 無線控制器 菁英版手把-黑色",
#     "price": "$4,999",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900I36FR/000001_1731995396.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900I36FR"
#   },
#   {
#     "name": "Xbox Elite 無線控制器 2代-輕裝版 (白)",
#     "price": "$4,299",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900J5R9L/000001_1756354022.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900J5R9L"
#   },
#   {
#     "name": "XBOX360 XBOX 無線控制器- 活力綠 遊戲手把 (相容 Xbox Series X|SWindows 10/11Android 和 iOS)",
#     "price": "$1,990",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900H5S7G/000001_1758613609.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900H5S7G"
#   },
#   {
#     "name": "RAZER 雷蛇 RAZER 雷蛇 Wolverine 金鋼狼 V3 Pro 無線電競手把 控制器 PC/Xbox 金剛狼",
#     "price": "$6,490",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE20A900HSLBV/000001_1725872283.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE20-A900HSLBV"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把 幻影紫 台灣公司貨",
#     "price": "$1,990",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900HTBCI/000001_1726630815.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900HTBCI"
#   },
#   {
#     "name": "Xbox 無線控制器 如霜之影 特別版",
#     "price": "$2,290",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900J97XW/000001_1758007850.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900J97XW"
#   },
#   {
#     "name": "Xbox XBOX 無線控制器 雷電之刃 特別版",
#     "price": "$2,290",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900J9813/000001_1758008138.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900J9813"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把 冰雪白 台灣公司貨",
#     "price": "$1,890",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900HPV0V/000001_1723033718.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900HPV0V"
#   },
#   {
#     "name": "ASUS ROG 華碩 ASUS ROG 雷切 Raikiri PRO無線控制器 XBOX手把 可用於XBOX/PC",
#     "price": "$3,990",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900GRLJ2/000001_1745810209.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900GRLJ2"
#   },
#   {
#     "name": "Xbox 無線控制器 -黑+ USB-C連接線",
#     "price": "$1,890",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900J5QZX/000001_1756351187.png?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900J5QZX"
#   },
#   {
#     "name": "Xbox 無線控制器 -黑",
#     "price": "$1,590",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900J5QZ5"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把 磨砂黑 台灣公司貨",
#     "price": "$1,890",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900HPV01"
#   },
#   {
#     "name": "Xbox 無線控制器 手把 原廠公司貨 狙擊紅/衝擊藍/電擊黃/磨砂黑+線材(多色選一)",
#     "price": "$1,690",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900G6D1O"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把 狙擊紅 台灣公司貨",
#     "price": "$1,690",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900HTBD3"
#   },
#   {
#     "name": "Xbox 無線控制器 -愛戀粉",
#     "price": "$1,690",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900J5R2M"
#   },
#   {
#     "name": "STEAM EPIC 隨插即用 遊戲手把 XBOX360 手把 有線 控制器 搖桿 手柄 雙震動 / 老爺子",
#     "price": "$599",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DSBE20-A900GWF4E"
#   },
#   {
#     "name": "Microsoft 微軟 【XBOX】Xbox 無線控制器《磨砂黑》",
#     "price": "$1,890",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DCBE1I-A900GOSE3"
#   },
#   {
#     "name": "Xbox 無線控制器 -狙擊紅",
#     "price": "$1,690",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900J5R8T"
#   },
#   {
#     "name": "XBOX Elite Series 2 菁英手把 無線控制器 輕裝版(白色)+接收器",
#     "price": "$4,680",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900JFWLF"
#   },
#   {
#     "name": "ASUS ROG 華碩 Raikiri 雷切手把 XBOX控制器 手把 可用於XBOX/PC",
#     "price": "$2,990",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900GDZCF"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把《緋紅領域》特別版 台灣公司貨",
#     "price": "$2,390",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900IE3WG"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】Xbox Elite 紅無線控制器2代手把-輕裝版 台灣公司貨",
#     "price": "$4,899",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900IH522"
#   },
#   {
#     "name": "Xbox Elite Series 2 菁英無線控制器2 (日本公司貨)+接收器",
#     "price": "$5,980",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900JFWMM"
#   },
#   {
#     "name": "XBOX Elite Series 2 菁英手把 無線控制器 輕裝版(藍色)+接收器",
#     "price": "$4,680",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900JFWLG"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把 愛戀粉 台灣公司貨",
#     "price": "$1,990",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900HPV11"
#   },
#   {
#     "name": "ASUS ROG 華碩 Raikiri 雷切手把 XBOX控制器 手把 台灣公司貨 可用於XBOX/PC",
#     "price": "$2,990",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900HHOTA/000001_1745810527.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900HHOTA"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】Xbox Elite 藍無線控制器2代手把-輕裝版 台灣公司貨",
#     "price": "$4,899",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900IH524/000001_1742355536.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900IH524"
#   },
#   {
#     "name": "Bteam Spark 搖桿 蘑菇頭 保護套 防滑 提升手把手感 - 適用Switch Pro PS5 DualSense XBOX 控制器 各式控制器",
#     "price": "$129",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJ8RA900HBRZ2/000001_1711005208.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJ8R-A900HBRZ2"
#   },
#   {
#     "name": "Microsoft 微軟 XBOX 手把 無線控制器+手把接收器(裸裝)組合-幻影紫",
#     "price": "$2,450",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900JD9H1/000001_1761104894.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900JD9H1"
#   },
#   {
#     "name": "ASUS 華碩 ROG 雷切 Raikiri Pro PC 無線控制器 手把 (Xbox/PC)",
#     "price": "$3,990",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900HZAH2/000001_1729134438.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900HZAH2"
#   },
#   {
#     "name": "【Razer雷蛇】 Wolverine V3 Pro 金鋼狼 無線電競控制器For PC / Xbox",
#     "price": "$6,490",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900HSE7K/000001_1752129952.png?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900HSE7K"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把 電擊黃 台灣公司貨",
#     "price": "$1,690",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900HPV0W/000001_1723033930.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900HPV0W"
#   },
#   {
#     "name": "Xbox 無線控制器 Elite Series 2 Core 白色 輕裝版 手把",
#     "price": "$4,899",
#     "img": "https://img.pchome.com.tw/cs/items/DSBC07A900FTDMW/000001_1755220255.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBC07-A900FTDMW"
#   },
#   {
#     "name": "Xbox XBOX 無線控制器 琉璃之心 特別版",
#     "price": "$2,290",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900J980C/000001_1758008014.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900J980C"
#   },
#   {
#     "name": "ASUS 華碩 ROG 雷切 Raikiri XBOX 控制器 手把 (Xbox/PC)",
#     "price": "$2,990",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900GDFHX/000001_1713231369.png?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900GDFHX"
#   },
#   {
#     "name": "XBOX 無線控制器 -衝擊藍",
#     "price": "$1,690",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900J5R7K/000001_1756353064.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900J5R7K"
#   },
#   {
#     "name": "Microsoft 微軟 XBOX 手把 無線控制器+手把接收器(裸裝)組合-衝擊藍",
#     "price": "$2,450",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900JD9GV/000001_1761104861.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900JD9GV"
#   },
#   {
#     "name": "Microsoft 微軟 Xbox 控制器 + 連接線",
#     "price": "$1,890",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJ8QA900J0P6B/000001_1763596031.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJ8Q-A900J0P6B"
#   },
#   {
#     "name": "OTTERBOX Xbox One 控制器抗菌防滑保護殼",
#     "price": "$1,207",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900BFCM7/000001_1622610141.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900BFCM7"
#   },
#   {
#     "name": "Microsoft 微軟 Xbox 無線控制器《叢林風暴》特別版 台灣公司貨",
#     "price": "$1,690",
#     "img": "https://img.pchome.com.tw/cs/items/DSBC8LA900I286A/000001_1731061212.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBC8L-A900I286A"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把《緋紅領域》特別版 台灣公司貨",
#     "price": "$2,090",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900IIHR2/000001_1743422096.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900IIHR2"
#   },
#   {
#     "name": "RAZER 雷蛇 Wolverine 金鋼狼 V3 Pro (白) 無線電競控制器 PC/Xbox 金剛狼",
#     "price": "$6,490",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900ID5JU/000001_1739785412.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900ID5JU"
#   },
#   {
#     "name": "HyperX Clutch Gladiate RGB 遊戲控制器 XBOX官方授權認證(7D6H2AA)",
#     "price": "$1,379",
#     "img": "https://img.pchome.com.tw/cs/items/DCAYW1A900JAT2F/000001_1759295103.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DCAYW1-A900JAT2F"
#   },
#   {
#     "name": "微軟 XBOX 無線控制器 特別版 如霜之影/琉璃之心/雷電之刃 遊戲手把 相容多平台",
#     "price": "$2,390",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900JA16D/000001_1758707676.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900JA16D"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把 狙擊紅 台灣公司貨",
#     "price": "$1,990",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900HPV10/000001_1723034455.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900HPV10"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把《叢林風暴》特別版 台灣公司貨",
#     "price": "$1,690",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900HZZWG/000001_1729569608.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900HZZWG"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把 幻影紫 台灣公司貨",
#     "price": "$1,990",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900HPV15/000001_1723034722.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900HPV15"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把 活力綠 台灣公司貨",
#     "price": "$1,990",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900HPV12/000001_1723034641.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900HPV12"
#   },
#   {
#     "name": "Microsoft 微軟 Xbox 無線控制器《冰雪白》",
#     "price": "$1,890",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJ8QA900J790Q/000001_1763600877.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJ8Q-A900J790Q"
#   },
#   {
#     "name": "Xbox 無線控制器(電擊黃)",
#     "price": "$1,437",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJCPA900J2MVY/000001_1753690463.png?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGAV0M-A900JDD81"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】Xbox 無線控制器 + USB-C 纜線 台灣公司貨",
#     "price": "$1,890",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900I7YNP/000001_1735612459.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900I7YNP"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】Xbox 無線控制器 + USB-C 纜線 台灣公司貨",
#     "price": "$1,890",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900I5M3W/000001_1733909875.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900I5M3W"
#   },
#   {
#     "name": "Microsoft 微軟 Xbox 無線控制器 磨砂黑 台灣公司貨",
#     "price": "$1,890",
#     "img": "https://img.pchome.com.tw/cs/items/DSBC8LA900I3KQY/000001_1732272892.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBC8L-A900I3KQY"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把 活力綠 台灣公司貨",
#     "price": "$1,690",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900I7YMQ/000001_1735611745.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900I7YMQ"
#   },
#   {
#     "name": "Microsoft 微軟 Xbox 無線控制器 磨砂黑XBOX無線控制器 + USB-C纜線",
#     "price": "$1,890",
#     "img": "https://img.pchome.com.tw/cs/items/DSBC8LA900I4M0R/000001_1733127672.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBC8L-A900I4M0R"
#   },
#   {
#     "name": "【Razer雷蛇】 Wolverine V3 Pro 金鋼狼 無線電競控制器 白For PC / Xbox",
#     "price": "$6,490",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900IDE3K/000001_1752130005.png?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900IDE3K"
#   },
#   {
#     "name": "Xbox 無線控制器 +USB-C 纜線(2.7m) 磨砂黑 遊戲手把(新包裝)",
#     "price": "$1,890",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900HK25G/000001_1758266309.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900HK25G"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把 衝擊藍 台灣公司貨",
#     "price": "$1,990",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900HPV0Z/000001_1723034395.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900HPV0Z"
#   },
#   {
#     "name": "Microsoft 微軟 Xbox 無線控制器 幻影紫 台灣公司貨",
#     "price": "$1,990",
#     "img": "https://img.pchome.com.tw/cs/items/DSBC8LA900I3KR5/000001_1732273014.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBC8L-A900I3KR5"
#   },
#   {
#     "name": "Xbox Xbox 無線控制器 「冰雪白」",
#     "price": "$1,590",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900J7RSK/000001_1759728127.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900J7RSK"
#   },
#   {
#     "name": "Xbox 無線控制器 手把(狙擊紅)",
#     "price": "$1,990",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-1900J4FPM"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】Xbox 無線控制器 -《 雷電之刃 》特別版 台灣公司貨",
#     "price": "$2,580",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900J8YHC"
#   },
#   {
#     "name": "Xbox 無線控制器 -白",
#     "price": "$1,590",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900J5QWB"
#   },
#   {
#     "name": "pump PlayStation 5 3D按鍵套8入 副廠PS5/PS4/Switch Pro/Xbox DualSense控制器手把搖桿套 搖桿帽",
#     "price": "$119",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJGC-A900AZM00"
#   },
#   {
#     "name": "HP 惠普 HyperX Clutch Gladiate - Wired Gaming Controller - Xbox 遊戲控制器(6L366AA)黑",
#     "price": "$1,379",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DCAYW1-A900JAT1X"
#   },
#   {
#     "name": "RAZER 雷蛇 Wolverine V3 Pro 金鋼狼 無線電競控制器(白)（For PC / Xbox)RZ06-05200200-R3M1",
#     "price": "$5,790",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJOYA900IJLK9/000001_1744342210.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJOY-A900IJLK9"
#   },
#   {
#     "name": "Xbox 無線控制器 手把(磨砂黑)",
#     "price": "$1,590",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAH1900J4FPS/000001_1757467076.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-1900J4FPS"
#   },
#   {
#     "name": "Microsoft 微軟 XBOX 手把 無線控制器+手把接收器(裸裝)組合-狙擊紅",
#     "price": "$2,450",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900JD9GG/000001_1761104886.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900JD9GG"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】Xbox 無線控制器 -《 琉璃之心 》特別版 台灣公司貨",
#     "price": "$2,580",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900J8YFA/000001_1757667595.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900J8YFA"
#   },
#   {
#     "name": "XBOX360 XBOX 無線控制器- 磨砂黑 遊戲手把 (相容XBOX Series X S、Windows 10/11、Android和iOS)",
#     "price": "$1,890",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900H5S5P/000001_1707279702.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900H5S5P"
#   },
#   {
#     "name": "RAZER 雷蛇 Wolverine V3 Pro 金鋼狼 無線電競控制器For PC Xbox RZ06-05200100-R3M1",
#     "price": "$6,490",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJOYA900HSEZ3/000001_1725607267.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJOY-A900HSEZ3"
#   },
#   {
#     "name": "Xbox ONE 無線控制器 菁英2",
#     "price": "$5,749",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJCPA900J5RBX/000001_1756355023.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJCP-A900J5RBX"
#   },
#   {
#     "name": "Xbox 無線控制器 活力綠",
#     "price": "$1,790",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900GAIJ2/000001_1738472952.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900GAIJ2"
#   },
#   {
#     "name": "Xbox 無線控制器硬殼包 無線手把收納包 防撞包 保護包",
#     "price": "$420",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJIVA900B02ZE/000001_1605855881.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJIV-A900B02ZE"
#   },
#   {
#     "name": "Xbox 無線控制器硬殼包 無線手把收納包 防撞包 保護包",
#     "price": "$420",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJIVA900C1Q4U/000001_1638322422.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJIV-A900C1Q4U"
#   },
#   {
#     "name": "微軟 磨砂黑 XBOX 無線控制器 + USB-C纜線",
#     "price": "$1,890",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900IM3RJ/000001_1745310868.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900IM3RJ"
#   },
#   {
#     "name": "XBOX 無線控制器 琉璃之心 特別版",
#     "price": "$1,947",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900J980C/000001_1758008014.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGAV0M-A900JCBYK"
#   },
#   {
#     "name": "XBOX360 無線控制器-白 ROBOT WHITE(新包裝)",
#     "price": "$1,890",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900J9KWK/000001_1758613031.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900J9KWK"
#   },
#   {
#     "name": "微軟 XBOX 無線控制器 叢林風暴 特別版 遊戲手把 相容多平台",
#     "price": "$1,870",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900HG1NY/000001_1714708634.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900HG1NY"
#   },
#   {
#     "name": "微軟 XBOX 無線控制器 多色",
#     "price": "$1,990",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900IM3RI/000001_1756278762.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900IM3RI"
#   },
#   {
#     "name": "IINE 良值 NS/PS/XBOX 遊戲片收纳架 卡帶光碟盒收納 4手把控制器支架 L866",
#     "price": "$350",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJK2B900IL2R7/000001_1744869557.png?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJK2-B900IL2R7"
#   },
#   {
#     "name": "XBOX 無線控制器 -活力綠",
#     "price": "$1,690",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900J5R4R/000001_1756352358.png?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900J5R4R"
#   },
#   {
#     "name": "XBOX360 無線控制器- 愛戀粉 遊戲手把(相容Windows 10/11、Android 和 iOS)新包裝",
#     "price": "$1,990",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900J9JMJ/000001_1758272556.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900J9JMJ"
#   },
#   {
#     "name": "Raymii 瑞米 GameArm LSA-65 PS XBOX SWITCH PC 遊戲控制器耳機收納支架 手把掛架 耳機架",
#     "price": "$849",
#     "img": "https://img.pchome.com.tw/cs/items/DCBBC5A900GYA6K/000001_1701151182.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DCBBC5-A900GYA6K"
#   },
#   {
#     "name": "Xbox 微軟 無線控制器 《叢林風暴》特別版 遊戲手把 相容多平台( Series X|SWindowsAndroidiOS)",
#     "price": "$1,890",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900HHCV6/000001_1715840663.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900HHCV6"
#   },
#   {
#     "name": "Microsoft 微軟 XBOX 手把 無線控制器+手把接收器(裸裝)組合-愛戀粉",
#     "price": "$2,450",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900JD9GE/000001_1761104878.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900JD9GE"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】Xbox Elite 藍無線控制器2代手把-輕裝版 台灣公司貨",
#     "price": "$4,899",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900IGZMK/000001_1742290411.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900IGZMK"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】Xbox Elite 紅無線控制器2代手把-輕裝版 台灣公司貨",
#     "price": "$4,899",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900IGZO5/000001_1742290945.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900IGZO5"
#   },
#   {
#     "name": "Xbox 無線控制器- 衝擊藍 遊戲手把 (相容XBOX Series X S、Windows 10/11、Android和iOS)",
#     "price": "$1,990",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900H5S73/000001_1707287361.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900H5S73"
#   },
#   {
#     "name": "微軟 XBOX 無線控制器 白色 黑色",
#     "price": "$1,890",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900IM3R1/000001_1745310827.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900IM3R1"
#   },
#   {
#     "name": "Microsoft 微軟 XBOX 手把 無線控制器 PC手把 毀滅戰士：黑暗時代 限量特仕版",
#     "price": "$2,290",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900JEE2P"
#   },
#   {
#     "name": "Microsoft 微軟 XBOX 手把 無線控制器+手把接收器(裸裝)組合-電擊黃",
#     "price": "$2,450",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900JD9GW"
#   },
#   {
#     "name": "Microsoft 微軟 Xbox 無線控制器 冰雪白 台灣公司貨",
#     "price": "$1,890",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DSBC8L-A900I3KQZ"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把《毀滅戰士：黑暗時代》特仕版 台灣公司貨",
#     "price": "$2,680",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900IS31D"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】 Xbox 無線控制器手把 電擊黃 台灣公司貨",
#     "price": "$1,690",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900I7YP7"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】Xbox 無線控制器 -《 琉璃之心 》特別版 台灣公司貨",
#     "price": "$2,290",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900JASM9"
#   },
#   {
#     "name": "Razer 雷蛇 WOLVERINE 金剛狼 V2 CHROMA Xbox / PC 有線控制器 金鋼狼",
#     "price": "$2,999",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900GPHYW"
#   },
#   {
#     "name": "Microsoft 微軟 【Microsoft 微軟】Xbox 無線控制器 - 琉璃之心 特別版 台灣公司貨",
#     "price": "$2,290",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900JESIM"
#   },
#   {
#     "name": "RAZER 雷蛇 Wolverine V3 Pro 金鋼狼 無線電競控制器(白)（For PC / Xbox)RZ06-05200200-R3M1",
#     "price": "$6,490",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJOY-A900ICZ5B"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】Xbox Elite 白無線控制器2代手把-輕裝版 台灣公司貨",
#     "price": "$4,899",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900ICZ1L"
#   },
#   {
#     "name": "Xbox Xbox 無線控制器 「叢林風暴」",
#     "price": "$1,690",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900J7RSN"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】Xbox 無線控制器 -《 如霜之影 》特別版 台灣公司貨",
#     "price": "$2,580",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900J8YD9"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】Xbox 無線控制器 -《 琉璃之心 》特別版 台灣公司貨",
#     "price": "$2,290",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900JEKKK"
#   },
#   {
#     "name": "【Razer雷蛇】Wolverine V3 金鋼狼 有線電競控制器 白For PC / Xbox",
#     "price": "$3,290",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DSBE20-A900IDIT7"
#   },
#   {
#     "name": "Xbox 【Microsoft 微軟】Xbox 無線控制器 -《 如霜之影 》特別版 台灣公司貨",
#     "price": "$2,290",
#     "img": "https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900JASMC"
#   },
#   {
#     "name": "Microsoft 微軟 【Microsoft 微軟】Xbox 無線控制器 - 雷電之刃 特別版 台灣公司貨",
#     "price": "$2,290",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900JESED/000001_1762151781.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900JESED"
#   },
#   {
#     "name": "Nintendo 任天堂 微軟 Xbox 無線控制器 - 《毀滅戰士：黑暗時代》",
#     "price": "$2,290",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1RA900IS7D2/000001_1746764956.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1R-A900IS7D2"
#   },
#   {
#     "name": "Microsoft 微軟 Xbox 無線控制器 毀滅戰士 : 黑暗時代 特仕款 台灣公司貨",
#     "price": "$2,290",
#     "img": "https://img.pchome.com.tw/cs/items/DSBC8LA900IS464/000001_1746705441.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBC8L-A900IS464"
#   },
#   {
#     "name": "Microsoft 微軟 【Microsoft 微軟】Xbox 無線控制器 - 如霜之影 特別版 台灣公司貨",
#     "price": "$2,290",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900JESEG/000001_1762151808.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900JESEG"
#   },
#   {
#     "name": "RAZER 雷蛇 WOLVERINE 金鋼狼 V2 CHROMA Xbox / PC 有線控制器可拆式 USB-C",
#     "price": "$2,999",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900FDT0L/000001_1725608431.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJAH-A900FDT0L"
#   },
#   {
#     "name": "微軟 磨砂黑 XBOX 無線控制器 + USB-C纜線",
#     "price": "$1,890",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900IM3RJ/000001_1745310868.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900IM3RJ"
#   },
#   {
#     "name": "微軟 XBOX 無線控制器 多色",
#     "price": "$1,990",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900IM3RI/000001_1756278762.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900IM3RI"
#   },
#   {
#     "name": "微軟 XBOX 無線控制器 叢林風暴 特別版 遊戲手把 相容多平台",
#     "price": "$1,870",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900HG1NY/000001_1714708634.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900HG1NY"
#   },
#   {
#     "name": "微軟 Xbox 無線控制器 - 叢林風暴",
#     "price": "$1,690",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900IM3RL/000001_1745310885.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900IM3RL"
#   },
#   {
#     "name": "【Microsoft 微軟】Xbox 無線控制器 -《 如霜之影 》特別版 台灣公司貨",
#     "price": "$2,290",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900JET3S/000001_1762162983.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900JET3S"
#   },
#   {
#     "name": "【Microsoft 微軟】Xbox 無線控制器 -《 琉璃之心 》特別版 台灣公司貨",
#     "price": "$2,290",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900JET3A/000001_1762162947.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900JET3A"
#   },
#   {
#     "name": "【Microsoft 微軟】Xbox 無線控制器 -《 雷電之刃 》特別版 台灣公司貨",
#     "price": "$2,290",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900JET3Q/000001_1762162954.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900JET3Q"
#   },
#   {
#     "name": "微軟 XBOX 無線控制器 特別版 如霜之影/琉璃之心/雷電之刃 遊戲手把 相容多平台",
#     "price": "$2,390",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900JA16D/000001_1758707676.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900JA16D"
#   },
#   {
#     "name": "XBOX 無線控制器 琉璃之心 特別版",
#     "price": "$1,947",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJAHA900J980C/000001_1758008014.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGAV0M-A900JCBYK"
#   },
#   {
#     "name": "HyperX Clutch Gladiate RGB 遊戲控制器 XBOX官方授權認證(7D6H2AA)",
#     "price": "$1,379",
#     "img": "https://img.pchome.com.tw/cs/items/DCAYW1A900JAT2F/000001_1759295103.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DCAYW1-A900JAT2F"
#   },
#   {
#     "name": "HP 惠普 HyperX Clutch Gladiate - Wired Gaming Controller - Xbox 遊戲控制器(6L366AA)黑",
#     "price": "$1,379",
#     "img": "https://img.pchome.com.tw/cs/items/DCAYW1A900JAT1X/000001_1759294549.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DCAYW1-A900JAT1X"
#   },
#   {
#     "name": "Xbox Elite 無線控制器2代-輕裝版",
#     "price": "$4,899",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900IM3RK/000001_1745310874.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900IM3RK"
#   },
#   {
#     "name": "微軟 Xbox Elite 無線控制器 Series 2 精英 菁英 手把",
#     "price": "$4,980",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1ZA900J9ZEI/000001_1758681596.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1Z-A900J9ZEI"
#   },
#   {
#     "name": "STEAM EPIC 隨插即用 遊戲手把 XBOX360 手把 有線 控制器 搖桿 手柄 雙震動 / 老爺子",
#     "price": "$599",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE20A900GWF4E/000001_1699861433.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE20-A900GWF4E"
#   },
#   {
#     "name": "Xbox 無線控制器硬殼包 無線手把收納包 防撞包 保護包",
#     "price": "$420",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJIVA900C1Q4U/000001_1638322422.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJIV-A900C1Q4U"
#   },
#   {
#     "name": "Xbox 無線控制器硬殼包 無線手把收納包 防撞包 保護包",
#     "price": "$420",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJIVA900B02ZE/000001_1605855881.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJIV-A900B02ZE"
#   },
#   {
#     "name": "Bteam Scabbard 遊戲控制器收納包 (NS2 / NS / PS5 / XBOX 控制器通用)",
#     "price": "$490",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1SA900JDU4G/000001_1761646008.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1S-A900JDU4G"
#   },
#   {
#     "name": "IINE 良值 NS/PS/XBOX 遊戲片收纳架 卡帶光碟盒收納 4手把控制器支架 L866",
#     "price": "$390",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJICA900IU7OC/000001_1747734143.png?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJIC-A900IU7OC"
#   },
#   {
#     "name": "良值 NS/PS/XBOX 遊戲片收架 黑白色 L866 卡帶光碟盒收納 4手把控制器支架",
#     "price": "$390",
#     "img": "https://img.pchome.com.tw/cs/items/DSBE1SA900ILW18/000001_1745223392.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DSBE1S-A900ILW18"
#   },
#   {
#     "name": "IINE 良值 NS/PS/XBOX 遊戲片收纳架 卡帶光碟盒收納 4手把控制器支架 L866",
#     "price": "$350",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJK2B900IL2R7/000001_1744869557.png?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJK2-B900IL2R7"
#   },
#   {
#     "name": "Raymii 瑞米 GameArm LSA-65 PS XBOX SWITCH PC 遊戲控制器耳機收納支架 手把掛架 耳機架",
#     "price": "$849",
#     "img": "https://img.pchome.com.tw/cs/items/DCBBC5A900GYA6K/000001_1701151182.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DCBBC5-A900GYA6K"
#   },
#   {
#     "name": "Bteam Spark 搖桿 蘑菇頭 保護套 防滑 提升手把手感 - 適用Switch Pro PS5 DualSense XBOX 控制器 各式控制器",
#     "price": "$129",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJ8RA900HBRZ2/000001_1711005208.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJ8R-A900HBRZ2"
#   },
#   {
#     "name": "pump PlayStation 5 3D按鍵套8入 副廠PS5/PS4/Switch Pro/Xbox DualSense控制器手把搖桿套 搖桿帽",
#     "price": "$119",
#     "img": "https://img.pchome.com.tw/cs/items/DGBJGCA900AZM00/000001_1618816905.jpg?width=480",
#     "href": "https://24h.pchome.com.tw/prod/DGBJGC-A900AZM00"
#   }
# ]
# 總筆數： 143

# %%
import json
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.common.exceptions import NoSuchElementException


def pchome(items):
    

    # 初始化瀏覽器
    service = Service()
    options = webdriver.ChromeOptions()
    options.add_argument("--start-maximized")
    options.add_argument("--incognito")
    options.add_argument("--disable-popup-blocking")

    driver = webdriver.Chrome(options=options)

    # 打開 PChome
    driver.get("https://24h.pchome.com.tw/")
    time.sleep(1)

    # 關閉跳窗
    try:
        driver.find_element(By.CSS_SELECTOR, ".c-popUp__endBtn > button").click()
    except:
        pass

    time.sleep(1)
    driver.find_element(By.CSS_SELECTOR, ".c-search__input").send_keys(items)
    driver.find_element(By.CSS_SELECTOR, ".c-search__btn.c-search__btn--search").click()
    try:
        no_result_text = driver.find_element(By.CSS_SELECTOR, ".c-tipsBox__text.c-tipsBox__text--regular500GrayDarkest").text
        if "找不到想要的商品" in no_result_text:
            print(f" PCHOME沒有這東東：{items}")
        return "找不到想要的商品"
    except NoSuchElementException:
                # 如果沒有找到商品列表，也沒有找到查無商品的提示，可能只是頁面載入問題，但我們在此處先返回。
                pass
    All_items = []
    page_count = 1
    
    while True:
        print(f"\n--- 正在爬取第 {page_count} 頁 ---")
        time.sleep(2)

        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)

        item_list = driver.find_elements(By.CSS_SELECTOR, ".c-listInfoGrid__item")
        for item in item_list:
            Product_name = item.find_element(By.CSS_SELECTOR, ".c-prodInfoV2__title").text
            Product_price = item.find_element(By.CSS_SELECTOR, ".c-prodInfoV2__price").text
            Product_img = item.find_element(By.CSS_SELECTOR, ".c-prodInfoV2__img > img").get_attribute("src")
            Product_href = item.find_element(By.CSS_SELECTOR, "a").get_attribute("href")

            All_items.append({
                "name": Product_name,
                "price": Product_price,
                "img": Product_img,
                "href": Product_href
            })

        # 找下一頁按鈕
        try:
            next_page_button = driver.find_element(
                By.CSS_SELECTOR, 
                "div.c-pagination__button.is-next > button:not([disabled])"
            )
            next_page_button.click()
            page_count += 1
            time.sleep(2)
        except NoSuchElementException:
            print("已到達最後一頁，停止爬取")
            break
    print("總筆數：", len(All_items))
    driver.quit()
    

    #      輸出 JSON 檔案
    filename = f"{items}.json"
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(All_items, f, ensure_ascii=False, indent=2)

    print("\n======================================")
    print(f"已將資料輸出至： {filename}")
    print("總筆數：", len(All_items))

    return All_items

# %%
pchome("dkjldl")
# Out:
#  PCHOME沒有這東東：dkjldl
# '找不到想要的商品'
